# %%
import numpy as np
from math import pi

import matplotlib.pyplot as plt
plt.style.use('ggplot')

from naca import NacaGenerator

# %%
gen = NacaGenerator(naca = '3524')

# %%
gen.generate_cosine_distribution();

# %%
gen.generate_naca();

# %%
gen.parse_naca(as_dict=True)
# Out:
# {'t': 0.24, 'm': 0.03, 'p': 0.5}

# %%
plt.plot(gen.x, gen.y_c, label = 'Curvature')
plt.plot(gen.x, gen.y_t, label = 'Thickness')

plt.legend()

# %%
plt.plot(gen.x, np.rad2deg(gen.theta))
plt.title('Theta Angle')
# Out:
# Text(0.5, 1.0, 'Theta Angle')

# %%
gen.plot()

# %%
N = 160

x_linear = np.linspace(0,1, N)
